# %%
from ultralytics import YOLO 
import cv2
import math

# %%
cap = cv2.VideoCapture(0)
cap.set(3, 640)
cap.set(4, 480)

model = YOLO("yolo-Weights/yolov8n.pt")

classNames = ["person", "bicycle", "car", "motorbike", "aeroplane", "bus", "train", "truck", "boat",
              "traffic light", "fire hydrant", "stop sign", "parking meter", "bench", "bird", "cat",
              "dog", "horse", "sheep", "cow", "elephant", "bear", "zebra", "giraffe", "backpack", "umbrella",
              "handbag", "tie", "suitcase", "frisbee", "skis", "snowboard", "sports ball", "kite", "baseball bat",
              "baseball glove", "skateboard", "surfboard", "tennis racket", "bottle", "wine glass", "cup",
              "fork", "knife", "spoon", "bowl", "banana", "apple", "sandwich", "orange", "broccoli",
              "carrot", "hot dog", "pizza", "donut", "cake", "chair", "sofa", "pottedplant", "bed",
              "diningtable", "toilet", "tvmonitor", "laptop", "mouse", "remote", "keyboard", "cell phone",
              "microwave", "oven", "toaster", "sink", "refrigerator", "book", "clock", "vase", "scissors",
              "teddy bear", "hair drier", "toothbrush"
              ]


while True:
    success, img = cap.read()
    results = model(img, stream=True)

    # coordinates
    for r in results:
        boxes = r.boxes

        for box in boxes:
            # bounding box
            x1, y1, x2, y2 = box.xyxy[0]
            x1, y1, x2, y2 = int(x1), int(y1), int(x2), int(y2) # convert to int values

            # put box in cam
            cv2.rectangle(img, (x1, y1), (x2, y2), (255, 0, 255), 3)

            # confidence
            confidence = math.ceil((box.conf[0]*100))/100
            print("Confidence --->",confidence)

            # class name
            cls = int(box.cls[0])
            print("Class name -->", classNames[cls])

            # object details
            org = [x1, y1]
            font = cv2.FONT_HERSHEY_SIMPLEX
            fontScale = 1
            color = (255, 0, 0)
            thickness = 2

            cv2.putText(img, classNames[cls], org, font, fontScale, color, thickness)

    cv2.imshow('Webcam', img)
    if cv2.waitKey(1) == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# 0: 480x640 1 person, 133.9ms
# Confidence ---> 0.31
# Class name --> person
# Speed: 3.0ms preprocess, 133.9ms inference, 1441.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 131.7ms
# Confidence ---> 0.69
# Class name --> person
# Speed: 2.7ms preprocess, 131.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 131.0ms
# Confidence ---> 0.64
# Class name --> person
# Speed: 3.1ms preprocess, 131.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 126.3ms
# Confidence ---> 0.72
# Class name --> person
# Speed: 0.0ms preprocess, 126.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 117.9ms
# Confidence ---> 0.78
# Class name --> person
# Speed: 0.0ms preprocess, 117.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 139.0ms
# Confidence ---> 0.55
# Class name --> person
# Speed: 0.0ms preprocess, 139.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 112.3ms
# Confidence ---> 0.64
# Class name --> person
# Speed: 4.5ms preprocess, 112.3ms inference, 15.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 121.1ms
# Confidence ---> 0.59
# Class name --> person
# Confidence ---> 0.37
# Class name --> person
# Speed: 0.0ms preprocess, 121.1ms inference, 15.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 129.5ms
# Confidence ---> 0.57
# Class name --> person
# Confidence ---> 0.35
# Class name --> person
# Speed: 0.0ms preprocess, 129.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 137.4ms
# Confidence ---> 0.73
# Class name --> person
# Speed: 0.0ms preprocess, 137.4ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 130.3ms
# Confidence ---> 0.67
# Class name --> person
# Speed: 2.0ms preprocess, 130.3ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 124.8ms
# Confidence ---> 0.56
# Class name --> person
# Speed: 1.5ms preprocess, 124.8ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 122.3ms
# Confidence ---> 0.74
# Class name --> person
# Speed: 1.5ms preprocess, 122.3ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 127.3ms
# Confidence ---> 0.6
# Class name --> person
# Confidence ---> 0.27
# Class name --> person
# Speed: 2.5ms preprocess, 127.3ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 119.8ms
# Confidence ---> 0.63
# Class name --> person
# Speed: 1.5ms preprocess, 119.8ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 127.8ms
# Confidence ---> 0.61
# Class name --> person
# Confidence ---> 0.26
# Class name --> person
# Speed: 1.5ms preprocess, 127.8ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 137.9ms
# Confidence ---> 0.69
# Class name --> person
# Speed: 4.0ms preprocess, 137.9ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 120.8ms
# Confidence ---> 0.53
# Class name --> person
# Confidence ---> 0.27
# Class name --> person
# Speed: 2.0ms preprocess, 120.8ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 121.8ms
# Confidence ---> 0.48
# Class name --> person
# Speed: 2.0ms preprocess, 121.8ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 130.3ms
# Confidence ---> 0.69
# Class name --> person
# Speed: 2.0ms preprocess, 130.3ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 122.8ms
# Confidence ---> 0.7
# Class name --> person
# Speed: 2.0ms preprocess, 122.8ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 130.3ms
# Confidence ---> 0.59
# Class name --> person
# Speed: 2.0ms preprocess, 130.3ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 121.8ms
# Confidence ---> 0.28
# Class name --> person
# Speed: 1.5ms preprocess, 121.8ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 124.8ms
# Confidence ---> 0.36
# Class name --> person
# Speed: 2.0ms preprocess, 124.8ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 122.3ms
# Confidence ---> 0.53
# Class name --> person
# Speed: 2.0ms preprocess, 122.3ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 123.7ms
# Confidence ---> 0.56
# Class name --> person
# Speed: 1.5ms preprocess, 123.7ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 120.3ms
# Confidence ---> 0.34
# Class name --> person
# Confidence ---> 0.34
# Class name --> person
# Speed: 2.5ms preprocess, 120.3ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 117.3ms
# Confidence ---> 0.59
# Class name --> person
# Speed: 2.0ms preprocess, 117.3ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 126.3ms
# Confidence ---> 0.62
# Class name --> person
# Speed: 1.5ms preprocess, 126.3ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 122.3ms
# Confidence ---> 0.65
# Class name --> person
# Speed: 1.5ms preprocess, 122.3ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 123.8ms
# Confidence ---> 0.67
# Class name --> person
# Speed: 1.5ms preprocess, 123.8ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 122.8ms
# Confidence ---> 0.65
# Class name --> person
# Speed: 1.5ms preprocess, 122.8ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 120.3ms
# Confidence ---> 0.74
# Class name --> person
# Speed: 2.0ms preprocess, 120.3ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 122.3ms
# Confidence ---> 0.74
# Class name --> person
# Speed: 2.0ms preprocess, 122.3ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 124.8ms
# Confidence ---> 0.75
# Class name --> person
# Speed: 2.0ms preprocess, 124.8ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 122.8ms
# Confidence ---> 0.5
# Class name --> person
# Confidence ---> 0.27
# Class name --> person
# Speed: 1.5ms preprocess, 122.8ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 122.3ms
# Confidence ---> 0.56
# Class name --> person
# Speed: 2.0ms preprocess, 122.3ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 123.3ms
# Confidence ---> 0.66
# Class name --> person
# Speed: 2.0ms preprocess, 123.3ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 116.3ms
# Confidence ---> 0.6
# Class name --> person
# Confidence ---> 0.26
# Class name --> person
# Speed: 2.0ms preprocess, 116.3ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 125.8ms
# Speed: 2.0ms preprocess, 125.8ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 126.3ms
# Speed: 2.0ms preprocess, 126.3ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 120.8ms
# Confidence ---> 0.32
# Class name --> person
# Speed: 1.5ms preprocess, 120.8ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 120.3ms
# Confidence ---> 0.39
# Class name --> person
# Speed: 1.5ms preprocess, 120.3ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 119.4ms
# Confidence ---> 0.44
# Class name --> person
# Speed: 2.0ms preprocess, 119.4ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 121.8ms
# Speed: 2.0ms preprocess, 121.8ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 118.3ms
# Speed: 1.5ms preprocess, 118.3ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bottle, 124.8ms
# Confidence ---> 0.37
# Class name --> bottle
# Speed: 2.5ms preprocess, 124.8ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# 0: 480x640 1 bottle, 1 remote, 117.3ms
# Confidence ---> 0.29
# Class name --> bottle
# Confidence ---> 0.26
# Class name --> remote
# Speed: 2.0ms preprocess, 117.3ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 118.3ms
# Confidence ---> 0.4
# Class name --> bottle
# Confidence ---> 0.3
# Class name --> person
# Speed: 1.5ms preprocess, 118.3ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bottle, 200.5ms
# Confidence ---> 0.36
# Class name --> bottle
# Speed: 2.5ms preprocess, 200.5ms inference, 3.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bottle, 203.5ms
# Confidence ---> 0.51
# Class name --> bottle
# Speed: 3.0ms preprocess, 203.5ms inference, 3.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 210.1ms
# Confidence ---> 0.36
# Class name --> person
# Speed: 3.5ms preprocess, 210.1ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 209.1ms
# Confidence ---> 0.28
# Class name --> person
# Speed: 2.5ms preprocess, 209.1ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 206.0ms
# Speed: 3.0ms preprocess, 206.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 215.1ms
# Speed: 3.0ms preprocess, 215.1ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 212.6ms
# Speed: 4.5ms preprocess, 212.6ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 cell phone, 205.5ms
# Confidence ---> 0.64
# Class name --> cell phone
# Speed: 3.5ms preprocess, 205.5ms inference, 3.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 203.5ms
# Speed: 3.5ms preprocess, 203.5ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 cell phone, 208.1ms
# Confidence ---> 0.58
# Class name --> cell phone
# Speed: 4.0ms preprocess, 208.1ms inference, 3.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 206.1ms
# Speed: 3.0ms preprocess, 206.1ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 206.6ms
# Speed: 3.5ms preprocess, 206.6ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 cell phone, 209.1ms
# Confidence ---> 0.65
# Class name --> cell phone
# Speed: 3.0ms preprocess, 209.1ms inference, 3.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 remote, 1 cell phone, 201.5ms
# Confidence ---> 0.6
# Class name --> cell phone
# Confidence ---> 0.37
# Class name --> remote
# Speed: 4.0ms preprocess, 201.5ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 remote, 1 cell phone, 216.1ms
# Confidence ---> 0.66
# Class name --> cell phone
# Confidence ---> 0.37
# Class name --> remote
# Speed: 3.5ms preprocess, 216.1ms inference, 3.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cell phone, 212.1ms
# Confidence ---> 0.62
# Class name --> cell phone
# Confidence ---> 0.34
# Class name --> person
# Speed: 3.0ms preprocess, 212.1ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 skateboard, 205.0ms
# Confidence ---> 0.36
# Class name --> skateboard
# Speed: 3.5ms preprocess, 205.0ms inference, 3.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 cell phone, 205.0ms
# Confidence ---> 0.38
# Class name --> cell phone
# Speed: 3.0ms preprocess, 205.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 cell phone, 119.8ms
# Confidence ---> 0.41
# Class name --> cell phone
# Speed: 2.5ms preprocess, 119.8ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 cell phone, 117.3ms
# Confidence ---> 0.29
# Class name --> cell phone
# Speed: 2.0ms preprocess, 117.3ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 118.3ms
# Speed: 1.5ms preprocess, 118.3ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 cell phone, 119.8ms
# Confidence ---> 0.7
# Class name --> cell phone
# Speed: 1.5ms preprocess, 119.8ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 cell phone, 112.3ms
# Confidence ---> 0.63
# Class name --> cell phone
# Speed: 2.0ms preprocess, 112.3ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 cell phone, 120.8ms
# Confidence ---> 0.71
# Class name --> cell phone
# Speed: 2.0ms preprocess, 120.8ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 cell phone, 115.3ms
# Confidence ---> 0.7
# Class name --> cell phone
# Speed: 2.0ms preprocess, 115.3ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 cell phone, 118.8ms
# Confidence ---> 0.62
# Class name --> cell phone
# Speed: 1.5ms preprocess, 118.8ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 cell phone, 123.9ms
# Confidence ---> 0.61
# Class name --> cell phone
# Speed: 1.5ms preprocess, 123.9ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 cell phone, 118.3ms
# Confidence ---> 0.6
# Class name --> cell phone
# Speed: 1.5ms preprocess, 118.3ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 cell phone, 121.3ms
# Confidence ---> 0.65
# Class name --> cell phone
# Speed: 2.5ms preprocess, 121.3ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 cell phone, 118.8ms
# Confidence ---> 0.61
# Class name --> cell phone
# Speed: 1.5ms preprocess, 118.8ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 cell phone, 121.3ms
# Confidence ---> 0.61
# Class name --> cell phone
# Speed: 1.5ms preprocess, 121.3ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 cell phone, 126.3ms
# Confidence ---> 0.52
# Class name --> cell phone
# Speed: 2.0ms preprocess, 126.3ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 cell phone, 117.3ms
# Confidence ---> 0.41
# Class name --> cell phone
# Speed: 1.5ms preprocess, 117.3ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 cell phone, 122.8ms
# Confidence ---> 0.58
# Class name --> cell phone
# Speed: 2.0ms preprocess, 122.8ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 remote, 1 cell phone, 121.8ms
# Confidence ---> 0.51
# Class name --> cell phone
# Confidence ---> 0.37
# Class name --> remote
# Speed: 1.5ms preprocess, 121.8ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 cell phone, 112.8ms
# Confidence ---> 0.55
# Class name --> cell phone
# Speed: 2.0ms preprocess, 112.8ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 remote, 1 cell phone, 123.8ms
# Confidence ---> 0.59
# Class name --> cell phone
# Confidence ---> 0.51
# Class name --> remote
# Speed: 2.0ms preprocess, 123.8ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 remote, 1 cell phone, 120.5ms
# Confidence ---> 0.58
# Class name --> cell phone
# Confidence ---> 0.52
# Class name --> remote
# Speed: 1.8ms preprocess, 120.5ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 cell phone, 120.3ms
# Confidence ---> 0.57
# Class name --> cell phone
# Speed: 1.5ms preprocess, 120.3ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 cell phone, 122.3ms
# Confidence ---> 0.69
# Class name --> cell phone
# Speed: 2.0ms preprocess, 122.3ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 remote, 1 cell phone, 123.8ms
# Confidence ---> 0.59
# Class name --> cell phone
# Confidence ---> 0.32
# Class name --> remote
# Speed: 2.0ms preprocess, 123.8ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 cell phone, 121.3ms
# Confidence ---> 0.43
# Class name --> cell phone
# Speed: 2.0ms preprocess, 121.3ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 skateboard, 1 cell phone, 120.3ms
# Confidence ---> 0.4
# Class name --> cell phone
# Confidence ---> 0.26
# Class name --> skateboard
# Speed: 1.5ms preprocess, 120.3ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
# 0: 480x640 1 cell phone, 120.3ms
# Confidence ---> 0.43
# Class name --> cell phone
# Speed: 2.0ms preprocess, 120.3ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 cell phone, 115.3ms
# Confidence ---> 0.42
# Class name --> cell phone
# Speed: 2.0ms preprocess, 115.3ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 cell phone, 115.8ms
# Confidence ---> 0.43
# Class name --> cell phone
# Speed: 1.5ms preprocess, 115.8ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 cell phone, 123.3ms
# Confidence ---> 0.49
# Class name --> cell phone
# Speed: 2.0ms preprocess, 123.3ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 119.8ms
# Speed: 1.5ms preprocess, 119.8ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 174.0ms
# Speed: 1.5ms preprocess, 174.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 bottle, 205.6ms
# Confidence ---> 0.71
# Class name --> bottle
# Speed: 2.9ms preprocess, 205.6ms inference, 3.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 215.1ms
# Speed: 3.5ms preprocess, 215.1ms inference, 3.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 205.0ms
# Speed: 3.0ms preprocess, 205.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 208.1ms
# Confidence ---> 0.73
# Class name --> person
# Speed: 3.0ms preprocess, 208.1ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 200.5ms
# Confidence ---> 0.69
# Class name --> person
# Speed: 4.0ms preprocess, 200.5ms inference, 3.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 210.6ms
# Confidence ---> 0.55
# Class name --> person
# Speed: 3.0ms preprocess, 210.6ms inference, 3.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 210.6ms
# Confidence ---> 0.59
# Class name --> person
# Speed: 3.0ms preprocess, 210.6ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 216.1ms
# Confidence ---> 0.8
# Class name --> person
# Speed: 3.0ms preprocess, 216.1ms inference, 3.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 207.6ms
# Confidence ---> 0.78
# Class name --> person
# Speed: 3.5ms preprocess, 207.6ms inference, 3.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 200.5ms
# Confidence ---> 0.76
# Class name --> person
# Speed: 3.5ms preprocess, 200.5ms inference, 3.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 209.1ms
# Speed: 4.0ms preprocess, 209.1ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 271.2ms
# Confidence ---> 0.73
# Class name --> person
# Confidence ---> 0.52
# Class name --> person
# Confidence ---> 0.37
# Class name --> person
# Speed: 2.5ms preprocess, 271.2ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 210.1ms
# Confidence ---> 0.63
# Class name --> person
# Confidence ---> 0.29
# Class name --> person
# Speed: 3.0ms preprocess, 210.1ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 206.0ms
# Confidence ---> 0.72
# Class name --> person
# Speed: 3.0ms preprocess, 206.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 216.6ms
# Confidence ---> 0.73
# Class name --> person
# Speed: 3.0ms preprocess, 216.6ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 203.0ms
# Confidence ---> 0.78
# Class name --> person
# Speed: 3.5ms preprocess, 203.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 208.0ms
# Confidence ---> 0.73
# Class name --> person
# Confidence ---> 0.65
# Class name --> person
# Speed: 3.0ms preprocess, 208.0ms inference, 3.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 208.5ms
# Confidence ---> 0.72
# Class name --> person
# Speed: 3.0ms preprocess, 208.5ms inference, 3.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 213.6ms
# Confidence ---> 0.74
# Class name --> person
# Speed: 3.0ms preprocess, 213.6ms inference, 3.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 206.6ms
# Confidence ---> 0.8
# Class name --> person
# Speed: 3.0ms preprocess, 206.6ms inference, 3.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 214.6ms
# Confidence ---> 0.69
# Class name --> person
# Speed: 3.5ms preprocess, 214.6ms inference, 3.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 146.4ms
# Confidence ---> 0.55
# Class name --> person
# Speed: 3.5ms preprocess, 146.4ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 120.8ms
# Confidence ---> 0.48
# Class name --> person
# Confidence ---> 0.27
# Class name --> person
# Speed: 2.0ms preprocess, 120.8ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 cat, 121.3ms
# Confidence ---> 0.45
# Class name --> cat
# Speed: 1.5ms preprocess, 121.3ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 cat, 134.9ms
# Confidence ---> 0.53
# Class name --> cat
# Speed: 2.0ms preprocess, 134.9ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 115.8ms
# Confidence ---> 0.3
# Class name --> person
# Speed: 2.0ms preprocess, 115.8ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 117.8ms
# Speed: 1.5ms preprocess, 117.8ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 117.8ms
# Confidence ---> 0.42
# Class name --> person
# Speed: 2.0ms preprocess, 117.8ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 115.3ms
# Speed: 2.0ms preprocess, 115.3ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 113.3ms
# Speed: 2.0ms preprocess, 113.3ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 118.3ms
# Speed: 1.5ms preprocess, 118.3ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 122.3ms
# Confidence ---> 0.4
# Class name --> person
# Speed: 2.0ms preprocess, 122.3ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 101.8ms
# Speed: 1.5ms preprocess, 101.8ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 116.3ms
# Confidence ---> 0.54
# Class name --> person
# Speed: 1.6ms preprocess, 116.3ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 124.3ms
# Confidence ---> 0.4
# Class name --> person
# Speed: 3.0ms preprocess, 124.3ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 cat, 115.8ms
# Confidence ---> 0.35
# Class name --> cat
# Speed: 1.5ms preprocess, 115.8ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cat, 121.3ms
# Confidence ---> 0.38
# Class name --> person
# Confidence ---> 0.29
# Class name --> cat
# Speed: 2.0ms preprocess, 121.3ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 cat, 114.1ms
# Confidence ---> 0.41
# Class name --> cat
# Speed: 2.2ms preprocess, 114.1ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 120.8ms
# Speed: 1.5ms preprocess, 120.8ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 124.8ms
# Confidence ---> 0.41
# Class name --> person
# Speed: 2.0ms preprocess, 124.8ms inference, 3.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 132.3ms
# Speed: 2.0ms preprocess, 132.3ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 122.8ms
# Speed: 2.0ms preprocess, 122.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 117.3ms
# Confidence ---> 0.27
# Class name --> person
# Speed: 1.5ms preprocess, 117.3ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 114.8ms
# Confidence ---> 0.43
# Class name --> person
# Confidence ---> 0.36
# Class name --> person
# Speed: 1.5ms preprocess, 114.8ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cup, 122.8ms
# Confidence ---> 0.58
# Class name --> person
# Confidence ---> 0.3
# Class name --> cup
# Speed: 2.0ms preprocess, 122.8ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 132.4ms
# Confidence ---> 0.47
# Class name --> person
# Confidence ---> 0.35
# Class name --> person
# Speed: 2.0ms preprocess, 132.4ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 2 cups, 144.4ms
# Confidence ---> 0.75
# Class name --> person
# Confidence ---> 0.48
# Class name --> cup
# Confidence ---> 0.29
# Class name --> cup
# Speed: 1.0ms preprocess, 144.4ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 126.8ms
# Confidence ---> 0.51
# Class name --> person
# Speed: 2.0ms preprocess, 126.8ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 108.3ms
# Confidence ---> 0.35
# Class name --> person
# Confidence ---> 0.26
# Class name --> person
# Speed: 1.5ms preprocess, 108.3ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 cup, 130.9ms
# Confidence ---> 0.27
# Class name --> cup
# Speed: 1.5ms preprocess, 130.9ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cup, 128.3ms
# Confidence ---> 0.29
# Class name --> cup
# Confidence ---> 0.28
# Class name --> person
# Speed: 2.0ms preprocess, 128.3ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cup, 206.3ms
# Confidence ---> 0.4
# Class name --> person
# Confidence ---> 0.31
# Class name --> cup
# Speed: 1.5ms preprocess, 206.3ms inference, 5.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cup, 231.3ms
# Confidence ---> 0.52
# Class name --> person
# Confidence ---> 0.48
# Class name --> cup
# Speed: 3.3ms preprocess, 231.3ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 1 cup, 210.6ms
# Confidence ---> 0.49
# Class name --> cup
# Confidence ---> 0.42
# Class name --> person
# Confidence ---> 0.32
# Class name --> person
# Speed: 3.5ms preprocess, 210.6ms inference, 8.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cup, 232.1ms
# Confidence ---> 0.7
# Class name --> person
# Confidence ---> 0.33
# Class name --> cup
# Speed: 3.5ms preprocess, 232.1ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cup, 1 cell phone, 212.6ms
# Confidence ---> 0.64
# Class name --> person
# Confidence ---> 0.38
# Class name --> cup
# Confidence ---> 0.28
# Class name --> cell phone
# Speed: 4.0ms preprocess, 212.6ms inference, 3.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cup, 224.4ms
# Confidence ---> 0.75
# Class name --> person
# Confidence ---> 0.38
# Class name --> cup
# Speed: 3.2ms preprocess, 224.4ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cup, 218.6ms
# Confidence ---> 0.79
# Class name --> person
# Confidence ---> 0.26
# Class name --> cup
# Speed: 3.0ms preprocess, 218.6ms inference, 3.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 cup, 201.5ms
# Confidence ---> 0.72
# Class name --> person
# Confidence ---> 0.35
# Class name --> cup
# Speed: 3.5ms preprocess, 201.5ms inference, 3.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 209.6ms
# Confidence ---> 0.58
# Class name --> person
# Speed: 3.5ms preprocess, 209.6ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 209.1ms
# Confidence ---> 0.72
# Class name --> person
# Speed: 3.0ms preprocess, 209.1ms inference, 4.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 209.1ms
# Confidence ---> 0.69
# Class name --> person
# Speed: 3.5ms preprocess, 209.1ms inference, 3.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 203.0ms
# Confidence ---> 0.67
# Class name --> person
# Speed: 3.0ms preprocess, 203.0ms inference, 3.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 199.0ms
# Confidence ---> 0.69
# Class name --> person
# Speed: 3.0ms preprocess, 199.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 202.0ms
# Confidence ---> 0.66
# Class name --> person
# Speed: 3.0ms preprocess, 202.0ms inference, 3.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 202.0ms
# Confidence ---> 0.7
# Class name --> person
# Speed: 3.5ms preprocess, 202.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 208.1ms
# Confidence ---> 0.76
# Class name --> person
# Confidence ---> 0.61
# Class name --> person
# Speed: 3.0ms preprocess, 208.1ms inference, 3.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 190.1ms
# Confidence ---> 0.78
# Class name --> person
# Confidence ---> 0.65
# Class name --> person
# Speed: 3.5ms preprocess, 190.1ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 175.0ms
# Confidence ---> 0.72
# Class name --> person
# Confidence ---> 0.49
# Class name --> person
# Speed: 3.0ms preprocess, 175.0ms inference, 3.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 183.0ms
# Confidence ---> 0.71
# Class name --> person
# Confidence ---> 0.69
# Class name --> person
# Speed: 3.0ms preprocess, 183.0ms inference, 3.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 199.0ms
# Confidence ---> 0.7
# Class name --> person
# Confidence ---> 0.42
# Class name --> person
# Speed: 3.0ms preprocess, 199.0ms inference, 3.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 189.5ms
# Confidence ---> 0.73
# Class name --> person
# Speed: 3.5ms preprocess, 189.5ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 178.5ms
# Confidence ---> 0.68
# Class name --> person
# Confidence ---> 0.46
# Class name --> person
# Speed: 3.0ms preprocess, 178.5ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 186.5ms
# Confidence ---> 0.74
# Class name --> person
# Confidence ---> 0.67
# Class name --> person
# Speed: 2.5ms preprocess, 186.5ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 161.6ms
# Confidence ---> 0.7
# Class name --> person
# Confidence ---> 0.68
# Class name --> person
# Speed: 3.9ms preprocess, 161.6ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 189.5ms
# Confidence ---> 0.45
# Class name --> person
# Speed: 3.0ms preprocess, 189.5ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 194.0ms
# Confidence ---> 0.65
# Class name --> person
# Speed: 2.5ms preprocess, 194.0ms inference, 3.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 198.0ms
# Speed: 2.5ms preprocess, 198.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 185.5ms
# Speed: 3.0ms preprocess, 185.5ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 banana, 110.3ms
# Confidence ---> 0.27
# Class name --> banana
# Speed: 1.5ms preprocess, 110.3ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 112.8ms
# Confidence ---> 0.4
# Class name --> person
# Speed: 1.5ms preprocess, 112.8ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 107.8ms
# Confidence ---> 0.32
# Class name --> person
# Speed: 1.5ms preprocess, 107.8ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 110.8ms
# Confidence ---> 0.3
# Class name --> person
# Speed: 1.5ms preprocess, 110.8ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 119.8ms
# Confidence ---> 0.43
# Class name --> person
# Confidence ---> 0.4
# Class name --> person
# Speed: 2.0ms preprocess, 119.8ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 110.8ms
# Confidence ---> 0.32
# Class name --> person
# Speed: 1.5ms preprocess, 110.8ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# 0: 480x640 1 person, 110.8ms
# Confidence ---> 0.59
# Class name --> person
# Speed: 1.5ms preprocess, 110.8ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 113.8ms
# Confidence ---> 0.32
# Class name --> person
# Speed: 1.5ms preprocess, 113.8ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 108.3ms
# Confidence ---> 0.64
# Class name --> person
# Confidence ---> 0.54
# Class name --> person
# Speed: 2.0ms preprocess, 108.3ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 persons, 104.3ms
# Confidence ---> 0.61
# Class name --> person
# Confidence ---> 0.59
# Class name --> person
# Confidence ---> 0.59
# Class name --> person
# Speed: 1.5ms preprocess, 104.3ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 108.3ms
# Confidence ---> 0.45
# Class name --> person
# Confidence ---> 0.38
# Class name --> person
# Speed: 1.5ms preprocess, 108.3ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 106.8ms
# Speed: 2.0ms preprocess, 106.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 105.8ms
# Confidence ---> 0.27
# Class name --> person
# Speed: 2.0ms preprocess, 105.8ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 110.8ms
# Confidence ---> 0.45
# Class name --> person
# Speed: 1.5ms preprocess, 110.8ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 108.3ms
# Confidence ---> 0.51
# Class name --> person
# Speed: 2.0ms preprocess, 108.3ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 110.3ms
# Confidence ---> 0.32
# Class name --> person
# Confidence ---> 0.31
# Class name --> person
# Speed: 2.0ms preprocess, 110.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 113.3ms
# Confidence ---> 0.7
# Class name --> person
# Speed: 1.5ms preprocess, 113.3ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 103.8ms
# Confidence ---> 0.71
# Class name --> person
# Speed: 2.0ms preprocess, 103.8ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 107.8ms
# Confidence ---> 0.75
# Class name --> person
# Speed: 2.0ms preprocess, 107.8ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 84.2ms
# Confidence ---> 0.81
# Class name --> person
# Speed: 2.0ms preprocess, 84.2ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 107.8ms
# Confidence ---> 0.7
# Class name --> person
# Speed: 2.5ms preprocess, 107.8ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 107.3ms
# Confidence ---> 0.69
# Class name --> person
# Speed: 1.5ms preprocess, 107.3ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 109.8ms
# Confidence ---> 0.74
# Class name --> person
# Speed: 1.5ms preprocess, 109.8ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 102.3ms
# Confidence ---> 0.77
# Class name --> person
# Speed: 2.0ms preprocess, 102.3ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 115.8ms
# Confidence ---> 0.76
# Class name --> person
# Speed: 1.5ms preprocess, 115.8ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 172.5ms
# Confidence ---> 0.76
# Class name --> person
# Speed: 2.5ms preprocess, 172.5ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 183.5ms
# Confidence ---> 0.71
# Class name --> person
# Speed: 3.5ms preprocess, 183.5ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 204.0ms
# Confidence ---> 0.76
# Class name --> person
# Speed: 3.0ms preprocess, 204.0ms inference, 3.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 196.1ms
# Confidence ---> 0.81
# Class name --> person
# Speed: 3.0ms preprocess, 196.1ms inference, 3.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 persons, 167.4ms
# Confidence ---> 0.71
# Class name --> person
# Confidence ---> 0.33
# Class name --> person
# Speed: 3.5ms preprocess, 167.4ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 167.5ms
# Confidence ---> 0.79
# Class name --> person
# Speed: 3.0ms preprocess, 167.5ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
